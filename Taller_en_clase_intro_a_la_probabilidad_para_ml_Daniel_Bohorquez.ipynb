# %% [markdown]
# <a href="https://colab.research.google.com/gist/Nicolasb221/7f4337ea22f86725f5751a9f7c9617f3/copia-de-taller_en_clase_intro_a_la_probabilidad_para_ml_estudiante.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller en clase #1
# Generando numeros aleatorios en ptython.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.
# ## Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt


##Librerias para cada una de las distribuciones.

from scipy.stats import binom
from scipy.stats import geom
from scipy.stats import poisson
from scipy.stats import nbinom

from scipy.stats import uniform
from scipy.stats import expon
from scipy.stats import chi2
from scipy.stats import gamma

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=100000
m=3000
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
print("mean:", mean, "variance:",var, "skewness:",skew,"kurtosis", kurt)
r = bernoulli.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print(r.argmax())
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")

avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# mean: 0.3 variance: 0.21 skewness: 0.8728715609439694 kurtosis -1.2380952380952381
# 1
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.29788 var_est= 0.20914750560000003

# %%
# binomial con cierto p entre 0 y 1 y cierto n
nb,pb = 10, 0.5
Nb=N
mb=100


meanb, varb, skewb, kurtb = binom.stats(nb, pb, moments='mvsk')
print("media:", meanb, "varianza:", varb, "asimetría:", skewb, "curtosis:", kurtb)

rb= binom.rvs(nb, pb, size=Nb)
plt.plot(rb, color = 'red')
v_eb=rb.var()
m_eb=rb.mean()

plt.title(str(Nb)+ " puntos distribuidos Binomial con p = " + str(pb) + " y n = " + str(nb))
plt.show()

rb.sort()
plt.plot(rb, color = 'red')
plt.title(str(Nb)+" Puntos distribuidos Binomial ordenados con p="+str(pb)+ " y n= "+ str(nb))
plt.show()

plt.hist(rb, bins=mb, color = 'red')
plt.title("Histograma de los "+str(Nb)+" puntos distribuidos binomial con p="+str(pb) + " y n= "+ str(nb))
plt.show()

print("Varianza teórica=", varb, "media teórica=", meanb)
print("Varianza estimada=", v_eb, "media estimada=", m_eb)
# Out:
# media: 5.0 varianza: 2.5 asimetría: 0.0 curtosis: -0.2
# Varianza teórica= 2.5 media teórica= 5.0
# Varianza estimada= 2.5004556443999997 media estimada= 4.99334

# %%
# Geométrica con cierto p entre 0 y 1
pG = 0.3
NG=N
mG=mb


meanG, varG, skewG, kurtG = geom.stats(pG, moments='mvsk')
print("media:", meanG, "varianza:", varG, "asimetría:", skewG, "curtosis:", kurtG)
rG= geom.rvs(pG, size=NG)
plt.plot(rG, color = 'red')
m_eG=rG.mean()
v_eG=rG.var()

plt.title(str(NG)+ " puntos distribuidos Geometrica con p= " + str(pG))
plt.show()

rG.sort()
plt.plot(rG, color = 'red')
plt.title(str(NG)+" puntos distribuidos Geometrica ordenados con p="+str(pG))
plt.show()

plt.hist(rG, bins=mG, color = 'red')
plt.title("Histograma de los "+str(NG)+" puntos distribuidos Geometrica con p="+str(pG))
plt.show()

print("Varianza teórica=", varG, "media teórica=", meanG)
print("Varianza estimada=", v_eG, "media estimada=", m_eG)
# Out:
# media: 3.3333333333333335 varianza: 7.777777777777779 asimetría: 2.031888635868469 curtosis: 6.128571428571429
# Varianza teórica= 7.777777777777779 media teórica= 3.3333333333333335
# Varianza estimada= 7.6979250943999995 media estimada= 3.31584

# %%
# Poisson con cierto Lamnda L
L = 5
Np=N
mp=100


meanp, varp, skewp, kurtp = poisson.stats(L, moments='mvsk')
print("media:", meanp, "varianza:", varp, "asimetría:", skewp, "curtosis:", kurtp)
rp= poisson.rvs(L, size=Np)
plt.plot(rp, color = 'red')
m_ep=rp.mean()
v_ep=rp.var()

plt.title(str(Np)+ " puntos distribuidos Poisson con L= " + str(L))
plt.show()

rp.sort()
plt.plot(rp, color = 'red')
plt.title(str(Np)+" puntos distribuidos Poisson ordenados con L="+str(L))
plt.show()

plt.hist(rp, bins=mp, color = 'red')
plt.title("Histograma de los "+str(Np)+" puntos distribuidos Poisson con L="+str(L))
plt.show()

print("Varianza teórica=", varp, "media teórica=", meanp)
print("Varianza estimada=", v_ep, "media estimada=", m_ep)
# Out:
# media: 5.0 varianza: 5.0 asimetría: 0.4472135954999579 curtosis: 0.2
# Varianza teórica= 5.0 media teórica= 5.0
# Varianza estimada= 4.9872656951 media estimada= 4.99507

# %%
#Binomial negativa con parametro p después de r fallos
rbn,pbn = 5,0.5
Nbn=N
mbn=100


meanbn, varbn, skewbn, kurtbn = nbinom.stats(rbn, pbn, moments='mvsk')
print("media:", meanbn, "varianza:", varbn, "asimetría:", skewbn, "curtosis:", kurtbn)
rrbn= binom.rvs(rbn, pbn, size=Nbn)
plt.plot(rrbn, color = 'red')
m_ebn=rrbn.mean()
v_ebn=rrbn.var()
plt.title(str(Nbn)+ " puntos distribuidos Binomial con p= " + str(pbn) + " y n= " + str(rbn))
plt.show()

rrbn.sort()
plt.plot(rrbn, color = 'red')
plt.title(str(Nbn)+" puntos distribuidos Binomial ordenados con p="+str(pbn )+ " y n= "+ str(rbn))
plt.show()

plt.hist(rrbn, bins=mbn, color = 'red')
plt.title("Histograma de los "+str(Nbn)+" puntos distribuidos binomial con p="+str(pbn) + " y n= "+ str(rbn))
plt.show()

print("Varianza teórica=", varbn, "media teórica=", meanbn)
print("Varianza estimada=", v_ebn, "media estimada=", m_ebn)
# Out:
# media: 5.0 varianza: 10.0 asimetría: 0.9486832980505138 curtosis: 1.3
# Varianza teórica= 10.0 media teórica= 5.0
# Varianza estimada= 1.2405599775 media estimada= 2.49985

# %% [markdown]
# ## Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=1000
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r, color = 'green')
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
r.sort()
plt.plot(r, color = 'green')
plt.title(str(N)+" puntos distribuidos normales ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m, color = 'green')
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.971391002002103 var_est= 0.2653971302092896

# %%
# Uniforme entre 0 y 255
NC=1000
mC=300
 
meanU, varU, skewU, kurtU = uniform.stats(moments='mvsk')
rU=uniform.rvs(loc=0, scale=255, size=NC)
plt.plot(rU, color = 'green')
m_eU=rU.mean()
v_eU=rU.var()

plt.title(str(NC)+" puntos distribuidos uniformemente entre 0 y 255")
plt.show()

rU.sort()
plt.plot(rU, color = 'green')
plt.title(str(NC)+" puntos distribuidos uniformes ordenados")
plt.show()


plt.hist(rU, bins=mC, color = 'green')
plt.title("Histograma de los "+str(NC)+" puntos distribuidos uniformemente  entre 0 y 255")
plt.show()

print("Varianza teórica=", varU, "media teórica=", meanU)
print("Varianza estimada=", v_eU, "media estimada=", m_eU)
# Out:
# Varianza teórica= 0.08333333333333333 media teórica= 0.5
# Varianza estimada= 5434.444821414549 media estimada= 131.82023964436755

# %%
# Exponencial con Lamnda L
L=0.3
NC=1000
mC=300

 
meanL, varL, skewL, kurtL = expon.stats(moments='mvsk')
rL=expon.rvs(size=NC)
plt.plot(rL, color = 'green')
m_eL=rL.mean()
v_eL=rL.var()

plt.title(str(NC)+" puntos distribuidos exponecialmete con Lamnda= "+str(L))
plt.show()

rL.sort()
plt.plot(rL, color = 'green')
plt.title(str(NC)+" puntos distribuidos exponencialmente ordenados")
plt.show()

plt.hist(rL, bins=mC, color = 'green')
plt.title("Histograma de los "+str(NC)+" puntos distribuidos exponencialmete")
plt.show()

print("Varianza teórica=", varL, "media teórica=", meanL)
print("Varianza estimada=", v_eL, "media estimada=", m_eL)
# Out:
# Varianza teórica= 1.0 media teórica= 1.0
# Varianza estimada= 1.0567476767123827 media estimada= 1.037190769239367

# %%
#Chi cuadrada con K grados de libertad
K=3.0
NC=1000
mC=300
 
meanC2, varC2, skewC2, kurtC2 = chi2.stats(K, moments='mvsk')
rC2=chi2.rvs(K, size=NC)
plt.plot(rC2, color = 'green')
m_eC2=rC2.mean()
v_eC2=rC2.var()

plt.title(str(NC)+" puntos distribuidos Chi cuadrada con K= "+str(K))
plt.show()

rC2.sort()
plt.plot(rC2, color = 'green')
plt.title(str(NC)+" puntos distribuidos Chi cuadrada ordenados")
plt.show()

plt.hist(rC2, bins=mC, color = 'green')
plt.title("Histograma de los "+str(NC)+" puntos distribuidos Chi cuadrada")
plt.show()

print("Varianza teórica=", varC2, "media teórica=", meanC2)
print("Varianza estimada=", v_eC2, "media estimada=", m_eC2)
# Out:
# Varianza teórica= 6.0 media teórica= 3.0
# Varianza estimada= 5.820181557315513 media estimada= 2.9847159165865933

# %%
#Gamma con parametros k y theta t
k,t=2.54,0.43
theta=1/t
NC=1000
mC=300

meanGA, varGA, skewGA, kurtGA = gamma.stats(k, moments='mvsk')
rGA=gamma.rvs(k, scale=theta, size=NC)
plt.plot(rGA, color = 'green')
m_eGA=rGA.mean()
v_eGA=rGA.var()

plt.title(str(NC)+" puntos distribuidos Gamma con k= "+str(k))
plt.show()

rGA.sort()
plt.plot(rGA, color = 'green')
plt.title(str(NC)+" puntos distribuidos Gamma ordenados")
plt.show()

plt.hist(rGA, bins=mC, color = 'green')
plt.title("Histograma de los "+str(NC)+" puntos distribuidos Gamma")
plt.show()

print("Varianza teórica=", varGA, "media teórica=", meanGA)
print("Varianza estimada=", v_eGA, "media estimada=", m_eGA)
# Out:
# Varianza teórica= 2.54 media teórica= 2.54
# Varianza estimada= 11.476838494620024 media estimada= 5.64603491246046
